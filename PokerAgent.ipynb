# %% [markdown]
# <a href="https://colab.research.google.com/github/wheyland/poker/blob/main/PokerAgent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rlcard[torch]
# Out:
# Collecting rlcard[torch]
#   Downloading rlcard-1.2.0.tar.gz (269 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.0/269.0 kB 5.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.16.3 in /usr/local/lib/python3.11/dist-packages (from rlcard[torch]) (2.0.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from rlcard[torch]) (3.0.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from rlcard[torch]) (2.6.0+cu124)
# Requirement already satisfied: GitPython in /usr/local/lib/python3.11/dist-packages (from rlcard[torch]) (3.1.44)
# Collecting gitdb2 (from rlcard[torch])
#   Downloading gitdb2-4.0.2-py3-none-any.whl.metadata (383 bytes)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from rlcard[torch]) (3.10.0)
# Requirement already satisfied: gitdb>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb2->rlcard[torch]) (4.0.12)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->rlcard[torch]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->rlcard[torch]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->rlcard[torch]) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->rlcard[torch]) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->rlcard[torch]) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->rlcard[torch]) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->rlcard[torch]) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->rlcard[torch]) (2.9.0.post0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->rlcard[torch]) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->rlcard[torch]) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->rlcard[torch]) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->rlcard[torch]) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->rlcard[torch]) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->rlcard[torch])
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->rlcard[torch])
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->rlcard[torch])
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->rlcard[torch])
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->rlcard[torch])
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->rlcard[torch])
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->rlcard[torch])
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->rlcard[torch])
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->rlcard[torch])
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->rlcard[torch]) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->rlcard[torch]) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->rlcard[torch]) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->rlcard[torch])
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->rlcard[torch]) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->rlcard[torch]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->rlcard[torch]) (1.3.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb>=4.0.1->gitdb2->rlcard[torch]) (5.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->rlcard[torch]) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->rlcard[torch]) (3.0.2)
# Downloading gitdb2-4.0.2-py3-none-any.whl (1.1 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 5.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 124.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 93.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 41.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 108.6 MB/s eta 0:00:00
# Building wheels for collected packages: rlcard
#   Building wheel for rlcard (setup.py) ... done
#   Created wheel for rlcard: filename=rlcard-1.2.0-py3-none-any.whl size=325795 sha256=5829803284940509f5f63c8c6b70e05f37d298cd1bceff5165adec849a07e6cb
#   Stored in directory: /root/.cache/pip/wheels/05/85/10/9ce42203776b06686ffe36d932983a79be6dfa95638ecf500b
# Successfully built rlcard
# Installing collected packages: rlcard, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, gitdb2, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed gitdb2-4.0.2 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 rlcard-1.2.0

# %%
import rlcard
from rlcard.utils import set_seed, get_device, tournament, reorganize, Logger, plot_curve
from rlcard.agents import DQNAgent, RandomAgent
import torch
import os
import matplotlib.pyplot as plt
from google.colab import drive
import copy

log_dir = './nolimit_holdem_dqn_result/'
model_save_path = os.path.join(log_dir, 'model.pth')
os.makedirs(log_dir, exist_ok=True)



env_id = 'no-limit-holdem'
config = {
    'seed': 42,
    'game_num_players': 3,
}
env = rlcard.make(env_id, config=config)
set_seed(42)


device = get_device()


dqn_agent = DQNAgent(
    num_actions=env.num_actions,
    state_shape=env.state_shape[0],
    mlp_layers=[64,64], #64,64
    replay_memory_size=100000,   #20000
    batch_size=64, #64
    learning_rate=0.001,#0001
    discount_factor=0.99,
    epsilon_start=1.0,
    epsilon_end=0.1,
    epsilon_decay_steps=100000, #20000
    device=device,
    save_path=log_dir,
    save_every=1000
)

# Set agents in the environment (DQN agent plays against copies of itself)
#agents = [dqn_agent] + [dqn_agent for _ in range(env.num_players - 1)]
#env.set_agents(agents)


def train_dqn_agent(env, dqn_agent, num_episodes, evaluate_every, num_eval_games, log_dir):

    episode_log = []
    bb_hand_log = []
    win_rate_log = []
    agent_index = 0

    with Logger(log_dir) as logger:
        for episode in range(num_episodes):

            #training_agents = [dqn_agent] + [dqn_agent for _ in range(env.num_players - 1)]
            #training_agents=[dqn_agent] + [RandomAgent(num_actions=env.num_actions)]
            training_agents=[dqn_agent] + [dqn_agent] + [RandomAgent(num_actions=env.num_actions)]

            env.set_agents(training_agents)


            trajectories, payoffs = env.run(is_training=True)


            trajectories = reorganize(trajectories, payoffs)


            for ts in trajectories[agent_index]:
                dqn_agent.feed(ts)

            #Evaluate the agent's performance
            if episode % evaluate_every == 0:

                avg_reward_tournament = tournament(
                    env,
                    num_eval_games,
                )[agent_index]
                logger.log_performance(episode, avg_reward_tournament)


                total_payoff_custom = 0
                wins_custom = 0

                #eval_opponents = [RandomAgent(num_actions=env.num_actions) for _ in range(env.num_players - 1)]
                #env.set_agents([dqn_agent] + eval_opponents) # DQN agent uses eval_step now
                #env.set_agents([dqn_agent] + [RandomAgent(num_actions=env.num_actions)]) # DQN agent uses eval_step now
                env.set_agents([dqn_agent] + [dqn_agent]+ [RandomAgent(num_actions=env.num_actions)])

                for _ in range(num_eval_games):
                    _, payoffs_eval = env.run(is_training=False)
                    agent_payoff_this_hand = payoffs_eval[agent_index]
                    total_payoff_custom += agent_payoff_this_hand
                    if agent_payoff_this_hand > 0:
                        wins_custom += 1

                #calculate metrics
                avg_bb_hand_custom = total_payoff_custom / num_eval_games
                win_rate_custom = wins_custom / num_eval_games
                print(f"Episode: {episode}, Avg BB/Hand (vs Self): {avg_bb_hand_custom:.4f}, Win Rate (vs Self): {win_rate_custom:.4f}")
                episode_log.append(episode)
                bb_hand_log.append(avg_bb_hand_custom)
                win_rate_log.append(win_rate_custom)


                env.set_agents(training_agents)



        csv_path, fig_path = logger.csv_path, logger.fig_path
        #plot_curve(csv_path, fig_path, 'DQN No-Limit Holdem (Tournament vs Self)')


        save_path = os.path.join(log_dir, 'model.pth')
        torch.save(dqn_agent, save_path)
        print(f"Final model saved to {save_path}")

    return episode_log, bb_hand_log, win_rate_log

#num_episodes = 10000
#evaluate_every = 500
num_eval_games = 5000

num_episodes = 20000
evaluate_every = 1000


episode_log, bb_hand_log, win_rate_log = train_dqn_agent(
    env=env,
    dqn_agent=dqn_agent,
    num_episodes=num_episodes,
    evaluate_every=evaluate_every,
    num_eval_games=num_eval_games,
    log_dir=log_dir
)
# Out:
# --> Running on the GPU
#
# ----------------------------------------
#   episode      |  0
#   reward       |  1.1674
# ----------------------------------------
# Episode: 0, Avg BB/Hand (vs Self): 4.2642, Win Rate (vs Self): 0.4290
# INFO - Step 100, rl-loss: 4541.9443359375
# INFO - Copied model parameters to target network.
# INFO - Step 1099, rl-loss: 2627.96728515625
# INFO - Saved model checkpoint.
# INFO - Step 1100, rl-loss: 2469.59521484375
# INFO - Copied model parameters to target network.
# INFO - Step 1365, rl-loss: 3630.987060546875
# ----------------------------------------
#   episode      |  1000
#   reward       |  -0.107
# ----------------------------------------
# Episode: 1000, Avg BB/Hand (vs Self): 1.7242, Win Rate (vs Self): 0.3324
# INFO - Step 2099, rl-loss: 2129.808837890625
# INFO - Saved model checkpoint.
# INFO - Step 2100, rl-loss: 1890.812255859375
# INFO - Copied model parameters to target network.
# INFO - Step 2695, rl-loss: 2812.67041015625
# ----------------------------------------
#   episode      |  2000
#   reward       |  4.3816
# ----------------------------------------
# Episode: 2000, Avg BB/Hand (vs Self): 1.5946, Win Rate (vs Self): 0.3416
# INFO - Step 3099, rl-loss: 1842.6156005859375
# INFO - Saved model checkpoint.
# INFO - Step 3100, rl-loss: 2964.619873046875
# INFO - Copied model parameters to target network.
# INFO - Step 4031, rl-loss: 1913.32373046875
# ----------------------------------------
#   episode      |  3000
#   reward       |  2.3708
# ----------------------------------------
# Episode: 3000, Avg BB/Hand (vs Self): 0.7438, Win Rate (vs Self): 0.3616
# INFO - Step 4099, rl-loss: 3483.77294921875
# INFO - Saved model checkpoint.
# INFO - Step 4100, rl-loss: 3488.56494140625
# INFO - Copied model parameters to target network.
# INFO - Step 5099, rl-loss: 3061.603271484375
# INFO - Saved model checkpoint.
# INFO - Step 5100, rl-loss: 1901.8095703125
# INFO - Copied model parameters to target network.
# INFO - Step 5397, rl-loss: 2031.09716796875
# ----------------------------------------
#   episode      |  4000
#   reward       |  3.936
# ----------------------------------------
# Episode: 4000, Avg BB/Hand (vs Self): 3.5008, Win Rate (vs Self): 0.3758
# INFO - Step 6099, rl-loss: 2111.89111328125
# INFO - Saved model checkpoint.
# INFO - Step 6100, rl-loss: 2712.524658203125
# INFO - Copied model parameters to target network.
# INFO - Step 6707, rl-loss: 3326.286376953125
# ----------------------------------------
#   episode      |  5000
#   reward       |  0.5736
# ----------------------------------------
# Episode: 5000, Avg BB/Hand (vs Self): -0.7636, Win Rate (vs Self): 0.3630
# INFO - Step 7099, rl-loss: 4925.958984375
# INFO - Saved model checkpoint.
# INFO - Step 7100, rl-loss: 3335.13134765625
# INFO - Copied model parameters to target network.
# INFO - Step 8086, rl-loss: 2955.80224609375
# ----------------------------------------
#   episode      |  6000
#   reward       |  3.8866
# ----------------------------------------
# Episode: 6000, Avg BB/Hand (vs Self): 2.0466, Win Rate (vs Self): 0.3648
# INFO - Step 8099, rl-loss: 3030.01953125
# INFO - Saved model checkpoint.
# INFO - Step 8100, rl-loss: 2268.21533203125
# INFO - Copied model parameters to target network.
# INFO - Step 9099, rl-loss: 2537.50244140625
# INFO - Saved model checkpoint.
# INFO - Step 9100, rl-loss: 2808.44921875
# INFO - Copied model parameters to target network.
# INFO - Step 9470, rl-loss: 2934.813232421875
# ----------------------------------------
#   episode      |  7000
#   reward       |  -0.9182
# ----------------------------------------
# Episode: 7000, Avg BB/Hand (vs Self): 2.4704, Win Rate (vs Self): 0.3806
# INFO - Step 10099, rl-loss: 1778.7998046875
# INFO - Saved model checkpoint.
# INFO - Step 10100, rl-loss: 2311.946533203125
# INFO - Copied model parameters to target network.
# INFO - Step 10833, rl-loss: 1518.93212890625
# ----------------------------------------
#   episode      |  8000
#   reward       |  4.1164
# ----------------------------------------
# Episode: 8000, Avg BB/Hand (vs Self): 2.0164, Win Rate (vs Self): 0.3636
# INFO - Step 11099, rl-loss: 3511.529296875
# INFO - Saved model checkpoint.
# INFO - Step 11100, rl-loss: 4215.44873046875
# INFO - Copied model parameters to target network.
# INFO - Step 12099, rl-loss: 2261.982421875
# INFO - Saved model checkpoint.
# INFO - Step 12100, rl-loss: 2539.210205078125
# INFO - Copied model parameters to target network.
# INFO - Step 12250, rl-loss: 3051.92578125
# ----------------------------------------
#   episode      |  9000
#   reward       |  0.4046
# ----------------------------------------
# Episode: 9000, Avg BB/Hand (vs Self): 2.8366, Win Rate (vs Self): 0.3834
# INFO - Step 13099, rl-loss: 1463.5662841796875
# INFO - Saved model checkpoint.
# INFO - Step 13100, rl-loss: 4180.1826171875
# INFO - Copied model parameters to target network.
# INFO - Step 13598, rl-loss: 3343.65283203125
# ----------------------------------------
#   episode      |  10000
#   reward       |  2.0652
# ----------------------------------------
# Episode: 10000, Avg BB/Hand (vs Self): -1.3152, Win Rate (vs Self): 0.3682
# INFO - Step 14099, rl-loss: 2873.572998046875
# INFO - Saved model checkpoint.
# INFO - Step 14100, rl-loss: 3698.8388671875
# INFO - Copied model parameters to target network.
# INFO - Step 14984, rl-loss: 3919.17724609375
# ----------------------------------------
#   episode      |  11000
#   reward       |  1.357
# ----------------------------------------
# Episode: 11000, Avg BB/Hand (vs Self): 2.3286, Win Rate (vs Self): 0.3840
# INFO - Step 15099, rl-loss: 1534.5672607421875
# INFO - Saved model checkpoint.
# INFO - Step 15100, rl-loss: 2313.48486328125
# INFO - Copied model parameters to target network.
# INFO - Step 16099, rl-loss: 2659.8857421875
# INFO - Saved model checkpoint.
# INFO - Step 16100, rl-loss: 2854.69189453125
# INFO - Copied model parameters to target network.
# INFO - Step 16384, rl-loss: 3227.951171875
# ----------------------------------------
#   episode      |  12000
#   reward       |  -0.3348
# ----------------------------------------
# Episode: 12000, Avg BB/Hand (vs Self): -0.0874, Win Rate (vs Self): 0.3784
# INFO - Step 17099, rl-loss: 2654.48779296875
# INFO - Saved model checkpoint.
# INFO - Step 17100, rl-loss: 3209.9560546875
# INFO - Copied model parameters to target network.
# INFO - Step 17814, rl-loss: 1650.325439453125
# ----------------------------------------
#   episode      |  13000
#   reward       |  2.841
# ----------------------------------------
# Episode: 13000, Avg BB/Hand (vs Self): 1.1370, Win Rate (vs Self): 0.3776
# INFO - Step 18099, rl-loss: 3185.84326171875
# INFO - Saved model checkpoint.
# INFO - Step 18100, rl-loss: 3629.08837890625
# INFO - Copied model parameters to target network.
# INFO - Step 19099, rl-loss: 3422.08056640625
# INFO - Saved model checkpoint.
# INFO - Step 19100, rl-loss: 4261.23046875
# INFO - Copied model parameters to target network.
# INFO - Step 19232, rl-loss: 2258.4052734375
# ----------------------------------------
#   episode      |  14000
#   reward       |  1.9896
# ----------------------------------------
# Episode: 14000, Avg BB/Hand (vs Self): 3.1548, Win Rate (vs Self): 0.3930
# INFO - Step 20099, rl-loss: 4452.306640625
# INFO - Saved model checkpoint.
# INFO - Step 20100, rl-loss: 3127.181640625
# INFO - Copied model parameters to target network.
# INFO - Step 20658, rl-loss: 3077.86767578125
# ----------------------------------------
#   episode      |  15000
#   reward       |  1.1154
# ----------------------------------------
# Episode: 15000, Avg BB/Hand (vs Self): 4.5202, Win Rate (vs Self): 0.3922
# INFO - Step 21099, rl-loss: 3873.14404296875
# INFO - Saved model checkpoint.
# INFO - Step 21100, rl-loss: 2286.568115234375
# INFO - Copied model parameters to target network.
# INFO - Step 22099, rl-loss: 2493.749267578125
# INFO - Saved model checkpoint.
# INFO - Step 22100, rl-loss: 4026.65966796875
# INFO - Copied model parameters to target network.
# INFO - Step 22119, rl-loss: 3744.8662109375
# ----------------------------------------
#   episode      |  16000
#   reward       |  2.542
# ----------------------------------------
# Episode: 16000, Avg BB/Hand (vs Self): 1.4740, Win Rate (vs Self): 0.3918
# INFO - Step 23099, rl-loss: 1422.378173828125
# INFO - Saved model checkpoint.
# INFO - Step 23100, rl-loss: 4710.09814453125
# INFO - Copied model parameters to target network.
# INFO - Step 23518, rl-loss: 3465.73779296875
# ----------------------------------------
#   episode      |  17000
#   reward       |  3.3182
# ----------------------------------------
# Episode: 17000, Avg BB/Hand (vs Self): 2.0284, Win Rate (vs Self): 0.3866
# INFO - Step 24099, rl-loss: 3055.477783203125
# INFO - Saved model checkpoint.
# INFO - Step 24100, rl-loss: 3468.835693359375
# INFO - Copied model parameters to target network.
# INFO - Step 24928, rl-loss: 2716.69384765625
# ----------------------------------------
#   episode      |  18000
#   reward       |  3.3418
# ----------------------------------------
# Episode: 18000, Avg BB/Hand (vs Self): 2.2232, Win Rate (vs Self): 0.3722
# INFO - Step 25099, rl-loss: 4554.11474609375
# INFO - Saved model checkpoint.
# INFO - Step 25100, rl-loss: 3338.410400390625
# INFO - Copied model parameters to target network.
# INFO - Step 26099, rl-loss: 3264.835693359375
# INFO - Saved model checkpoint.
# INFO - Step 26100, rl-loss: 3658.24169921875
# INFO - Copied model parameters to target network.
# INFO - Step 26353, rl-loss: 3283.86181640625
# ----------------------------------------
#   episode      |  19000
#   reward       |  2.753
# ----------------------------------------
# Episode: 19000, Avg BB/Hand (vs Self): 1.5610, Win Rate (vs Self): 0.3826
# INFO - Step 27099, rl-loss: 3118.9453125
# INFO - Saved model checkpoint.
# INFO - Step 27100, rl-loss: 4310.115234375
# INFO - Copied model parameters to target network.
# INFO - Step 27816, rl-loss: 3507.33349609375Final model saved to ./nolimit_holdem_dqn_result/model.pth
#
# Logs saved in ./nolimit_holdem_dqn_result/

# %%
import pandas as pd
#Training progress
log_dir = './nolimit_holdem_dqn_result/'
file_path = os.path.join(log_dir, 'performance.csv')

df = pd.read_csv("./nolimit_holdem_dqn_result/performance.csv")



plt.figure(figsize=(9, 5))
plt.plot(df["episode"], df["reward"], linewidth=2)

plt.title("Training Reward vs Episode")
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#evaluation Metrics
if episode_log:
  plt.figure(figsize=(12, 5))

  plt.subplot(1, 2, 1) #BB/Hand
  #plt.figure(figsize=(10, 5))
  plt.plot(episode_log, bb_hand_log, marker='.')
  plt.xlabel("Training Episode")
  plt.ylabel("Average BB/Hand")
  plt.title("BB/Hand")
  plt.grid(True)

  plt.subplot(1, 2, 2) #win Rate
  #plt.figure(figsize=(10, 5))
  plt.plot(episode_log, win_rate_log, marker='.', color='orange')
  plt.xlabel("Training Episode")
  plt.ylabel("Win Rate")
  plt.title("Win Rate")
  plt.ylim(0, 1.05)
  plt.grid(True)


  plt.suptitle(f"Training Agent Performance ({num_episodes} episdoes)")
  plt.tight_layout(rect=[0, 0.03, 1, 0.95])
  plt.show()

print("Training and evaluation complete.")
# Out:
# Training and evaluation complete.

# %%
import rlcard
import torch
import os
import matplotlib.pyplot as plt
from rlcard.agents import DQNAgent, RandomAgent


env_id = 'no-limit-holdem'
config = {
    'seed': 42,
    'game_num_players': 2,
}
env = rlcard.make(env_id, config=config)
set_seed(42)

def evaluate_dqn_vs_random(env, model_path, num_eval_games_test, eval_batch_size, device):
    loaded_dqn_agent = torch.load(model_path, map_location=device, weights_only=False )
    loaded_dqn_agent.set_device(device) # Ensure device is set after loading

    env.set_agents([loaded_dqn_agent] + [RandomAgent(num_actions=env.num_actions)])
    #env.set_agents([loaded_dqn_agent] + [dqn_agent])

    dqn_agent_index = 0
    random_agent_tracked_index = 1 # Track the first random agent (at index 1)

    eval_game_log = []
    #DQN Agent metrics
    bb_hand_log_dqn = []
    win_rate_log_dqn = []
    total_payoff_all_dqn = 0
    wins_all_dqn = 0
    #Random Agent metrics
    bb_hand_log_rand = []
    win_rate_log_rand = []
    total_payoff_all_rand = 0
    wins_all_rand = 0


    for game_batch_start in range(0, num_eval_games_test, eval_batch_size):
        batch_end = min(game_batch_start + eval_batch_size, num_eval_games_test)
        num_games_in_batch = batch_end - game_batch_start
        if num_games_in_batch <= 0: continue

        total_payoff_batch_dqn = 0
        wins_batch_dqn = 0
        total_payoff_batch_rand = 0
        wins_batch_rand = 0

        print(f"  Evaluating games {game_batch_start + 1} to {batch_end}")
        for game_num in range(num_games_in_batch):
          _, payoffs = env.run(is_training=False)

          # DQN Agent (Index 0)
          dqn_payoff_this_hand = payoffs[dqn_agent_index]
          total_payoff_batch_dqn += dqn_payoff_this_hand
          wins_batch_dqn += 1 if dqn_payoff_this_hand > 0 else 0

          # Random Agent (Index 1)
          rand_payoff_this_hand = payoffs[random_agent_tracked_index]
          total_payoff_batch_rand += rand_payoff_this_hand
          wins_batch_rand += 1 if rand_payoff_this_hand > 0 else 0



        #Calculate metrics
        # DQN
        avg_bb_hand_batch_dqn = total_payoff_batch_dqn / num_games_in_batch if num_games_in_batch > 0 else 0
        win_rate_batch_dqn = wins_batch_dqn / num_games_in_batch if num_games_in_batch > 0 else 0
        # Random
        avg_bb_hand_batch_rand = total_payoff_batch_rand / num_games_in_batch if num_games_in_batch > 0 else 0
        win_rate_batch_rand = wins_batch_rand / num_games_in_batch if num_games_in_batch > 0 else 0

        eval_game_log.append(batch_end) # Log
        # DQN
        bb_hand_log_dqn.append(avg_bb_hand_batch_dqn)
        win_rate_log_dqn.append(win_rate_batch_dqn)
        # Random
        bb_hand_log_rand.append(avg_bb_hand_batch_rand)
        win_rate_log_rand.append(win_rate_batch_rand)


        # DQN
        total_payoff_all_dqn += total_payoff_batch_dqn
        wins_all_dqn += wins_batch_dqn
        # Random
        total_payoff_all_rand += total_payoff_batch_rand
        wins_all_rand += wins_batch_rand


    # DQN
    final_avg_bb_hand_dqn = total_payoff_all_dqn / num_eval_games_test if num_eval_games_test > 0 else 0
    final_win_rate_dqn = wins_all_dqn / num_eval_games_test if num_eval_games_test > 0 else 0
    # Random
    final_avg_bb_hand_rand = total_payoff_all_rand / num_eval_games_test if num_eval_games_test > 0 else 0
    final_win_rate_rand = wins_all_rand / num_eval_games_test if num_eval_games_test > 0 else 0

    print("--- Final Evaluation Complete ---")
    print(f"Overall DQN (Agent {dqn_agent_index}) Avg BB/Hand vs Random: {final_avg_bb_hand_dqn:.4f}")
    print(f"Overall DQN (Agent {dqn_agent_index}) Win Rate vs Random: {final_win_rate_dqn:.4f}")
    print(f"Overall Tracked Random (Agent {random_agent_tracked_index}) Avg BB/Hand vs DQN+Random: {final_avg_bb_hand_rand:.4f}")
    print(f"Overall Tracked Random (Agent {random_agent_tracked_index}) Win Rate vs DQN+Random: {final_win_rate_rand:.4f}")

    return eval_game_log, bb_hand_log_dqn, win_rate_log_dqn, bb_hand_log_rand, win_rate_log_rand

# %%
num_eval_games_test = 15000
eval_batch_size = 500
eval_results = evaluate_dqn_vs_random(
    env=env,
    model_path=model_save_path,
    num_eval_games_test=num_eval_games_test,
    eval_batch_size=eval_batch_size,
    device=device
)


eval_game_log, bb_hand_log_dqn, win_rate_log_dqn, bb_hand_log_rand, win_rate_log_rand = eval_results





plt.figure(figsize=(15, 5))
#BB/Hand Subplot
plt.subplot(1, 2, 1)
#DQN Agent's BB/Hand
plt.plot(eval_game_log, bb_hand_log_dqn, marker='.', label='DQN Agent')
plt.plot(eval_game_log, bb_hand_log_rand, marker='.', linestyle='--', color='green', label='Random Agent')
plt.xlabel("Evaluation Game Number")
plt.ylabel("Average BB/Hand")
plt.title("Average BB/Hand")
plt.grid(True)
plt.legend()

#Win Rate Subplot
plt.subplot(1, 2, 2)
#DQN Agent's Win Rate
plt.plot(eval_game_log, win_rate_log_dqn, marker='.', color='orange', label='DQN Agent')
#Random Agent's Win Rate
plt.plot(eval_game_log, win_rate_log_rand, marker='.', linestyle='--', color='red', label='Random Agent')

plt.xlabel("Evaluation Game Number")
plt.ylabel("Win Rate")
plt.title("Win Rate")
plt.ylim(0, 1.05)
plt.grid(True)
plt.legend()


plt.suptitle(f"Final Performance: DQN vs Random Agent ({num_eval_games_test} games)")
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

plt.show()
# Out:
#   Evaluating games 1 to 500
#   Evaluating games 501 to 1000
#   Evaluating games 1001 to 1500
#   Evaluating games 1501 to 2000
#   Evaluating games 2001 to 2500
#   Evaluating games 2501 to 3000
#   Evaluating games 3001 to 3500
#   Evaluating games 3501 to 4000
#   Evaluating games 4001 to 4500
#   Evaluating games 4501 to 5000
#   Evaluating games 5001 to 5500
#   Evaluating games 5501 to 6000
#   Evaluating games 6001 to 6500
#   Evaluating games 6501 to 7000
#   Evaluating games 7001 to 7500
#   Evaluating games 7501 to 8000
#   Evaluating games 8001 to 8500
#   Evaluating games 8501 to 9000
#   Evaluating games 9001 to 9500
#   Evaluating games 9501 to 10000
#   Evaluating games 10001 to 10500
#   Evaluating games 10501 to 11000
#   Evaluating games 11001 to 11500
#   Evaluating games 11501 to 12000
#   Evaluating games 12001 to 12500
#   Evaluating games 12501 to 13000
#   Evaluating games 13001 to 13500
#   Evaluating games 13501 to 14000
#   Evaluating games 14001 to 14500
#   Evaluating games 14501 to 15000
# --- Final Evaluation Complete ---
# Overall DQN (Agent 0) Avg BB/Hand vs Random: 3.7687
# Overall DQN (Agent 0) Win Rate vs Random: 0.6703
# Overall Tracked Random (Agent 1) Avg BB/Hand vs DQN+Random: -3.7687
# Overall Tracked Random (Agent 1) Win Rate vs DQN+Random: 0.3148
